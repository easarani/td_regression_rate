# %% [markdown]
# # A Look Into Regression
#
# *Exploring wide receiver and tight end fantasy football data to determine if receiving yards and receiving touchdowns correlate. And buliding touchdown regression to help aid fantasy football owners in making roster decisions.*

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#First step: import needed libraries to explore and visualize the data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ***Airyards.com*** data is easily digestable and readily usable. First step was to pull in these ***.csv*** files using the pandas library. NFL data for the past 8 years was used in this analysis.

# %%
#Using airyards.com data, bring in .csv files to python
air_yards_12 = pd.read_csv("data/airyards12.csv")
air_yards_13 = pd.read_csv("data/airyards13.csv")
air_yards_14 = pd.read_csv("data/airyards14.csv")
air_yards_15 = pd.read_csv("data/airyards15.csv")
air_yards_16 = pd.read_csv("data/airyards16.csv")
air_yards_17 = pd.read_csv("data/airyards17.csv")
air_yards_18 = pd.read_csv("data/airyards18.csv")
air_yards_19 = pd.read_csv("data/airyards19.csv")

# %% [markdown]
# Inspecting a few datasets reveals each set has 16 columns with varying rows corresponding to each wide receiver and tight end receiving data for that particular season.

# %%
air_yards_12.tail() #Inspect the bottom 5 rows of the dataset
# Out:
#     Unnamed: 0       full_name position team  targets  rec  rec_yards  \
# 78          79        Jim Dray       TE  ARI        2    2         15
# 79          80    Andre Holmes       WR  DAL        2    2         11
# 80          81        Ted Ginn       WR   SF        2    2          1
# 81          82    Josh Bellamy       WR   KC        0    0          0
# 82          83  Matthew Slater       WR   NE        0    0          0
#
#     air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr  ppr
# 78         14    1   0   7.0  1.07    0.01       0.02  0.03  3.5
# 79         24    3   0  12.0  0.46    0.02       0.01  0.03  3.1
# 80         -4    5   0  -2.0 -0.25    0.00       0.01  0.01  2.8
# 81          0    0   0   NaN   NaN    0.00       0.00  0.00  0.0
# 82         13    0   0   inf  0.00    0.00       0.00  0.00  0.0

# %%
air_yards_13.head() #Inspect the top 5 rows of the dataset
# Out:
#    Unnamed: 0         full_name position team  targets  rec  rec_yards  \
# 0           1  Demaryius Thomas       WR  DEN      142   92       1430
# 1           2       Josh Gordon       WR  CLE      159   87       1646
# 2           3        A.J. Green       WR  CIN      178   98       1426
# 3           4      Jimmy Graham       TE   NO      142   86       1215
# 4           5  Brandon Marshall       WR  CHI      164  100       1295
#
#    air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
# 0       1385  707  14   9.8  1.03    0.27       0.21  0.50  319.0
# 1       2133  675   9  13.4  0.77    0.44       0.27  0.71  314.4
# 2       2232  390  11  12.5  0.64    0.45       0.30  0.77  306.6
# 3       1366  406  16   9.6  0.89    0.27       0.22  0.52  303.5
# 4       2000  279  12  12.2  0.65    0.40       0.28  0.70  301.5

# %% [markdown]
# The ***Unnamed*** column represents the ***ppr*** rank of each wide receiver/tight end for that year. The first column was renamed to reflect this description by using `.rename()`.

# %%
air_yards_12.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True) #.rename can accomplish this header name change
air_yards_13.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_14.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_15.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_16.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_17.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_18.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_19.rename(columns = {"Unnamed: 0" : "rank"}, inplace=True)
air_yards_19.head()
# Out:
#    rank        full_name position team  targets  rec  rec_yards  air_yards  \
# 0     1   Michael Thomas       WR   NO      185  149       1725       1488
# 1     2     Chris Godwin       WR   TB      121   86       1333       1301
# 2     3      Julio Jones       WR  ATL      157   99       1394       1913
# 3     4      Cooper Kupp       WR   LA      134   94       1161       1007
# 4     5  DeAndre Hopkins       WR  HOU      150  104       1165       1580
#
#    yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
# 0  583   9   8.0  1.16    0.40       0.32  0.75  374.6
# 1  577   9  10.8  1.02    0.23       0.22  0.49  274.1
# 2  364   6  12.2  0.73    0.37       0.25  0.63  274.1
# 3  538  10   7.5  1.15    0.21       0.21  0.46  270.5
# 4  387   7  10.5  0.74    0.34       0.30  0.69  264.3

# %% [markdown]
# Using `pd.concat`, we can merge all the datasets together to use for our exploratory processess and analysis.

# %%
#Use pd.concat to merge data frames together
concat_df = pd.concat([air_yards_12, air_yards_13, air_yards_14, air_yards_15, air_yards_16,air_yards_17, air_yards_18, air_yards_19], ignore_index=True, sort=False)
concat_df.sort_values("full_name").head(20) #sort by name
# Out:
#       rank        full_name position team  targets  rec  rec_yards  air_yards  \
# 1343    24       A.J. Brown       WR  TEN       84   52       1051       1107
# 1036   220       A.J. Derby       TE  MIA        9    2         20         95
# 941    125       A.J. Derby       TE  DEN       31   19        224        285
# 726    169       A.J. Derby       TE  DEN       20   16        160        135
# 806    249       A.J. Derby       TE   NE        0    0          0          0
# 595     38       A.J. Green       WR  CIN      100   66        964       1236
# 361      8       A.J. Green       WR  CIN      132   86       1297       1687
# 827     11       A.J. Green       WR  CIN      143   75       1078       1910
# 85       3       A.J. Green       WR  CIN      178   98       1426       2232
# 219     25       A.J. Green       WR  CIN      116   69       1041       1511
# 1        2       A.J. Green       WR  CIN      164   97       1350       2239
# 1106    46       A.J. Green       WR  CIN       76   45        683        949
# 751    194  Aaron Burbridge       WR   SF       16    7         88        141
# 1088    28   Adam Humphries       WR   TB      102   74        795        682
# 875     59   Adam Humphries       WR   TB       83   61        631        632
# 631     74   Adam Humphries       WR   TB       83   55        622        461
# 1423   104   Adam Humphries       WR  TEN       47   37        374        351
# 457    104   Adam Humphries       WR   TB       40   27        260        270
# 1263   203     Adam Shaheen       TE  CHI        6    5         48         59
# 960    144     Adam Shaheen       TE  CHI       14   12        127        101
#
#       yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
# 1343  465   8  13.2  0.95    0.29       0.19  0.48  217.1
# 1036   18   0  10.6  0.21    0.14       0.11  0.26    4.0
# 941    74   2   9.2  0.79    0.11       0.10  0.22   53.4
# 726    50   0   6.8  1.19    0.06       0.09  0.18   32.0
# 806     0   0   NaN   NaN    0.00       0.00  0.00    0.0
# 595   258   4  12.4  0.78    0.41       0.28  0.70  186.4
# 361   336  10  12.8  0.77    0.38       0.26  0.66  275.7
# 827   297   8  13.4  0.56    0.46       0.28  0.74  230.8
# 85    390  11  12.5  0.64    0.45       0.30  0.77  306.6
# 219   309   6  13.0  0.69    0.50       0.31  0.82  209.3
# 1     361  11  13.7  0.60    0.48       0.30  0.79  301.8
# 1106  161   6  12.5  0.72    0.37       0.23  0.61  149.3
# 751    43   0   8.8  0.62    0.04       0.03  0.08   15.8
# 1088  399   5   6.7  1.17    0.11       0.17  0.32  184.6
# 875   307   1   7.6  1.00    0.10       0.14  0.28  130.7
# 631   382   2   5.6  1.35    0.08       0.15  0.28  131.0
# 1423  120   2   7.5  1.07    0.13       0.14  0.30   86.5
# 457   123   1   6.8  0.96    0.07       0.10  0.20   59.0
# 1263   13   1   9.8  0.81    0.07       0.06  0.15   15.8
# 960    49   3   7.2  1.26    0.06       0.06  0.13   42.7

# %% [markdown]
# With so many rows (1634), I want to check for any null values and inspect data types and certain summary statistics. I created ***explore*** function to accomplish this. This exploratory and cleaning process aids in getting correct data to later perform accurate analysis.

# %%
def explore(df):
    exp_df = {}
    exp_df['max'] = df.max()
    exp_df['min'] = df.min()
    exp_df['mean'] = df.mean()
    exp_df['median'] = df.median()
    exp_df['null_sum'] = df.isnull().sum()
    exp_df['null_avg'] = df.isnull().mean()
    exp_df['dtypes'] = df.dtypes
    exp_df['count'] = df.count()
    
    return pd.DataFrame(exp_df)

explore(concat_df)
# Out:
#                  max         min        mean  median  null_sum  null_avg  \
# adot             inf          -3         inf    9.70        42  0.025704
# air_yards       2674         -13  526.641983  358.00         0  0.000000
# full_name  Zay Jones  A.J. Brown         NaN     NaN         0  0.000000
# ms_air          0.74       -0.01    0.141438    0.12         0  0.000000
# position          WR          TE         NaN     NaN         0  0.000000
# ppr            382.2           0   88.201958   62.60         0  0.000000
# racr             inf         -86         inf    0.78        45  0.027540
# rank             314           1  116.358017  105.00         0  0.000000
# rec              149           0   31.492044   23.00         0  0.000000
# rec_yards       1871          -4  397.146879  272.00         0  0.000000
# targets          203           0   50.637087   38.00         0  0.000000
# td                16           0    2.655447    2.00         0  0.000000
# team             WAS         ARI         NaN     NaN         0  0.000000
# tgt_share        0.4           0    0.113537    0.10         0  0.000000
# wopr            0.94           0    0.269486    0.23         0  0.000000
# yac              873          -4  144.548960  101.00         0  0.000000
#
#             dtypes  count
# adot       float64   1592
# air_yards    int64   1634
# full_name   object   1634
# ms_air     float64   1634
# position    object   1634
# ppr        float64   1634
# racr       float64   1589
# rank         int64   1634
# rec          int64   1634
# rec_yards    int64   1634
# targets      int64   1634
# td           int64   1634
# team        object   1634
# tgt_share  float64   1634
# wopr       float64   1634
# yac          int64   1634

# %% [markdown]
# Our data set consists of **int**, **float**, and **object** variables. Note that the ***count*** column does not sum to the same amount. We can see ***adot*** and ***racr*** have null values that we can replace with 0.  This can be accomplished by using `fillna()`.

# %%
concat_df["adot"] = concat_df["adot"].fillna(0) #changes NaN values to 0
concat_df["racr"] = concat_df["racr"].fillna(0) #changes Nan values to 0
concat_df.sort_values("full_name").head(20)
# Out:
#       rank        full_name position team  targets  rec  rec_yards  air_yards  \
# 1343    24       A.J. Brown       WR  TEN       84   52       1051       1107
# 1036   220       A.J. Derby       TE  MIA        9    2         20         95
# 941    125       A.J. Derby       TE  DEN       31   19        224        285
# 726    169       A.J. Derby       TE  DEN       20   16        160        135
# 806    249       A.J. Derby       TE   NE        0    0          0          0
# 595     38       A.J. Green       WR  CIN      100   66        964       1236
# 361      8       A.J. Green       WR  CIN      132   86       1297       1687
# 827     11       A.J. Green       WR  CIN      143   75       1078       1910
# 85       3       A.J. Green       WR  CIN      178   98       1426       2232
# 219     25       A.J. Green       WR  CIN      116   69       1041       1511
# 1        2       A.J. Green       WR  CIN      164   97       1350       2239
# 1106    46       A.J. Green       WR  CIN       76   45        683        949
# 751    194  Aaron Burbridge       WR   SF       16    7         88        141
# 1088    28   Adam Humphries       WR   TB      102   74        795        682
# 875     59   Adam Humphries       WR   TB       83   61        631        632
# 631     74   Adam Humphries       WR   TB       83   55        622        461
# 1423   104   Adam Humphries       WR  TEN       47   37        374        351
# 457    104   Adam Humphries       WR   TB       40   27        260        270
# 1263   203     Adam Shaheen       TE  CHI        6    5         48         59
# 960    144     Adam Shaheen       TE  CHI       14   12        127        101
#
#       yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
# 1343  465   8  13.2  0.95    0.29       0.19  0.48  217.1
# 1036   18   0  10.6  0.21    0.14       0.11  0.26    4.0
# 941    74   2   9.2  0.79    0.11       0.10  0.22   53.4
# 726    50   0   6.8  1.19    0.06       0.09  0.18   32.0
# 806     0   0   0.0  0.00    0.00       0.00  0.00    0.0
# 595   258   4  12.4  0.78    0.41       0.28  0.70  186.4
# 361   336  10  12.8  0.77    0.38       0.26  0.66  275.7
# 827   297   8  13.4  0.56    0.46       0.28  0.74  230.8
# 85    390  11  12.5  0.64    0.45       0.30  0.77  306.6
# 219   309   6  13.0  0.69    0.50       0.31  0.82  209.3
# 1     361  11  13.7  0.60    0.48       0.30  0.79  301.8
# 1106  161   6  12.5  0.72    0.37       0.23  0.61  149.3
# 751    43   0   8.8  0.62    0.04       0.03  0.08   15.8
# 1088  399   5   6.7  1.17    0.11       0.17  0.32  184.6
# 875   307   1   7.6  1.00    0.10       0.14  0.28  130.7
# 631   382   2   5.6  1.35    0.08       0.15  0.28  131.0
# 1423  120   2   7.5  1.07    0.13       0.14  0.30   86.5
# 457   123   1   6.8  0.96    0.07       0.10  0.20   59.0
# 1263   13   1   9.8  0.81    0.07       0.06  0.15   15.8
# 960    49   3   7.2  1.26    0.06       0.06  0.13   42.7

# %% [markdown]
# Re-casting our function **explore** should show that our ***count*** column's values are all similar and our null sum and average should now all be 0.

# %%
#Cast explore to check to see if we have rid ourselves of our null values
explore(concat_df)
# Out:
#                  max         min        mean  median  null_sum  null_avg  \
# adot             inf          -3         inf    9.60         0       0.0
# air_yards       2674         -13  526.641983  358.00         0       0.0
# full_name  Zay Jones  A.J. Brown         NaN     NaN         0       0.0
# ms_air          0.74       -0.01    0.141438    0.12         0       0.0
# position          WR          TE         NaN     NaN         0       0.0
# ppr            382.2           0   88.201958   62.60         0       0.0
# racr             inf         -86         inf    0.78         0       0.0
# rank             314           1  116.358017  105.00         0       0.0
# rec              149           0   31.492044   23.00         0       0.0
# rec_yards       1871          -4  397.146879  272.00         0       0.0
# targets          203           0   50.637087   38.00         0       0.0
# td                16           0    2.655447    2.00         0       0.0
# team             WAS         ARI         NaN     NaN         0       0.0
# tgt_share        0.4           0    0.113537    0.10         0       0.0
# wopr            0.94           0    0.269486    0.23         0       0.0
# yac              873          -4  144.548960  101.00         0       0.0
#
#             dtypes  count
# adot       float64   1634
# air_yards    int64   1634
# full_name   object   1634
# ms_air     float64   1634
# position    object   1634
# ppr        float64   1634
# racr       float64   1634
# rank         int64   1634
# rec          int64   1634
# rec_yards    int64   1634
# targets      int64   1634
# td           int64   1634
# team        object   1634
# tgt_share  float64   1634
# wopr       float64   1634
# yac          int64   1634

# %% [markdown]
# Now that we have explored our dataset and corrected our null values, we can group the dataset by name and determine if touchdowns and receiving yards correlate. We will separate wide receivers and tight ends in our analysis. Let us first begin with wide receivers:

# %% [markdown]
# ---

# %% [markdown]
# ## Wide Receiver - Receiving Yards to Touchdown Correlation

# %% [markdown]
# Let's first parse out only the wide receivers from our combined dataset and group by name followed by summation.

# %%
#Parse out WR data and then group by name to determine summation of yards and touchdowns
wr_total_df = concat_df[(concat_df.position == "WR")].groupby("full_name").sum()#group by name then total column values
wr_total_df[["rec_yards", "td", "ppr"]].sort_values("rec_yards", ascending = False).head(20)
# Out:
#                   rec_yards  td     ppr
# full_name
# Julio Jones           11144  48  2150.6
# Antonio Brown          9847  72  2172.5
# Demaryius Thomas       8931  57  1904.1
# DeAndre Hopkins        8613  54  1818.4
# T.Y. Hilton            8579  44  1678.1
# A.J. Green             7839  56  1659.9
# Larry Fitzgerald       7428  47  1709.7
# Golden Tate            7258  41  1593.6
# Emmanuel Sanders       7130  38  1508.3
# Mike Evans             7129  48  1459.9
# Alshon Jeffery         6645  45  1421.5
# Odell Beckham          6505  48  1409.9
# Keenan Allen           6397  33  1370.7
# DeSean Jackson         6273  33  1204.2
# Jarvis Landry          6171  32  1403.8
# Julian Edelman         6012  35  1395.6
# Randall Cobb           5978  43  1391.6
# Brandon Marshall       5967  48  1350.5
# Brandin Cooks          5719  34  1216.3
# Robert Woods           5564  25  1180.1

# %% [markdown]
# Using our summmation, we can graph ***rec_yards*** to ***td*** to see if a correlation exists. Seaborn's `.lmplot` makes for an easy to understand visualization.

# %%
# Use lmplot from seaborn library to plot
sns.lmplot(x="rec_yards", y="td", data=wr_total_df, scatter_kws={'color': 'black'}, line_kws={'color': 'red'})
                                                    #Red and black for Julio Jones
plt.gca().set_title("Receiving Yards v. Touchdowns")
plt.xlabel("WR Receiving Yards")
plt.ylabel("Touchdowns")
# Out:
# Text(10.049999999999997, 0.5, 'Touchdowns')

# %% [markdown]
# An obvious correlation exists. Use `LinearRegression()` to model relationship between ***rec_yards*** and ***td***. We can score the model to get our R^2 value for wide receivers.

# %%
# Use linear regression to see rec_yards and td correlation
model_rec_td = LinearRegression()
model_rec_td.fit(X = wr_total_df[["rec_yards"]], y = wr_total_df.td) #x value is receiving yards and y value is td
print(model_rec_td.score(X = wr_total_df[["rec_yards"]], y = wr_total_df.td)) #scores the model, shows R^2 value
# Out:
# 0.9269301679611535

# %% [markdown]
# Our WR **R^2** value is approx. **0.927**, proving a strong correlation between receving yards and touchdowns. We can calculate an average of how many receiving yards leads to a single touchdown.

# %%
# Find how many WR receiving yards leads to a TD to use for td_regression model
wr_total_rec_yards = wr_total_df.rec_yards.sum() #sums receiving yards column
wr_total_rec_td = wr_total_df.td.sum()
wr_ratio = wr_total_rec_yards/wr_total_rec_td
wr_ratio #this ratio is the average amount of WR receiving yards that correlates to one receiving touchdown
# Out:
# 158.35492312724892

# %% [markdown]
# A wide receiver scores a TD on, approximately, every **159** receiving yards.
#
# Now let's look at Tight Ends:

# %% [markdown]
# ---

# %% [markdown]
# ## Tight End - Receiving Yards to Touchdown Correlation

# %% [markdown]
# We will parse out only tight end data and group by name followed by summation.

# %%
#Parse out TE data and then group by name to determine summation of yards and touchdowns
te_total_df = concat_df[(concat_df.position == "TE")].groupby("full_name").sum()#group by name then total column values
te_total_df[["rec_yards", "td", "ppr"]].sort_values("rec_yards", ascending = False).head(20)
# Out:
#                    rec_yards  td     ppr
# full_name
# Travis Kelce            6459  37  1379.5
# Jimmy Graham            6211  58  1487.1
# Greg Olsen              5923  34  1275.3
# Zach Ertz               5733  35  1307.3
# Rob Gronkowski          5305  49  1166.5
# Jared Cook              4978  31  1065.8
# Delanie Walker          4762  31  1074.7
# Jason Witten            4495  26  1060.5
# Kyle Rudolph            3905  44  1053.5
# Vernon Davis            3759  28   823.3
# Antonio Gates           3725  38   934.5
# Charles Clay            3613  20   827.8
# Martellus Bennett       3441  26   819.1
# Jordan Reed             3355  24   809.3
# Eric Ebron              3183  26   767.6
# George Kittle           2945  12   585.7
# Coby Fleener            2785  20   637.7
# Benjamin Watson         2767  19   664.7
# Jermaine Gresham        2593  19   633.3
# Austin Hooper           2244  16   534.4

# %% [markdown]
# Again, Seaborn's `.lmplot` makes for an easy to understand correlation graphic.

# %%
#Use lmplot from seaborn library to plot
sns.lmplot(x="rec_yards", y="td", data=te_total_df, scatter_kws={'color': 'gray'}, line_kws={'color': 'blue'}) 
                                                    #gray and blue for Rob Gronkowski
plt.gca().set_title("Receiving Yards v. Touchdowns")
plt.xlabel("TE Receiving Yards")
plt.ylabel("Touchdowns")
# Out:
# Text(10.049999999999997, 0.5, 'Touchdowns')

# %% [markdown]
# As we found out earlier, receiving yards and touchdowns correlate, which is reinforced looking at this tight end specific plot. Use `LinearRegression()` to model a relationship between ***rec_yards*** and ***td***. We can score the model to get our R^2 value for tight ends.

# %%
# Use linear regression to see rec_yards and td correlation for tight ends
model_rec_td = LinearRegression()
model_rec_td.fit(X = te_total_df[["rec_yards"]], y = te_total_df.td) #x value is receiving yards and y value is td
print(model_rec_td.score(X = te_total_df[["rec_yards"]], y = te_total_df.td)) #scores the model, shows R^2 value
# Out:
# 0.8805433215650749

# %% [markdown]
# Our TE **R^2** value is approx. **0.881** showing a strong correlation. Let us now calculate an average of receiving yards to touchdowns for tight ends.

# %%
# Find how many TE receiving yards leads to a TD to use for td_regression model
te_total_rec_yards = te_total_df.rec_yards.sum() #sums receiving yards column
te_total_rec_td = te_total_df.td.sum()
te_ratio = te_total_rec_yards/te_total_rec_td
te_ratio #this ratio is the average amount of TE receiving yards that correlates to one receiving touchdown
# Out:
# 128.58580343213728

# %% [markdown]
# A tight end scores a TD on, approximately, every **129** receiving yards.
#
# Now let's build our regression rate:

# %% [markdown]
# ---

# %% [markdown]
# ## Determining Touchdown Regression Rate

# %% [markdown]
# Now that we know that receiving yards and tochdowns correlate strongly, we can make a function to determine a player's touchdown regression rate. We need to be sure to use the right receiving yards/touchdown ratio depeding on the player's position (WR or TE). The average wide receiver scores a touchdown on approximately every 159 receiving yards. The average tight end scores a touchdown on approximately every 129 receiving yards. Let us build two functions:
#
# + **The first function *positional* will take in two variables (a dataframe and a string) and return the correct postional sorted dataframe. The string - "pos" is the corresponding position we wish to investigate (WR or TE).**
# + **The second function *regression_air_yards* will take in two variables (a dataframe and the corresponding positional td_ratio). This function creates a column and calculates the touchdown regression rate for each player for a given year.**
#
# Running *positional* as the dataframe in *regression_air_yards* outputs our sorted dataframe with corresponding touchdown regression rate column. The only values we input are:
# 1. dataframe year
# 2. position
# 3. positional ratio

# %%
#Define a function positional to pull in the wanted dataset and filter out unwanted positional players
def positional(air_yards_table, pos):
    if (pos == "WR"):
        hold = air_yards_table.loc[(air_yards_table.position == "WR")].copy()#Make copy to avoid "SettingwithCopyWarning"
    else:
        hold = air_yards_table.loc[(air_yards_table.position == "TE")].copy()
    return hold


#We can now define a function that take in our dataframe made from "positional" and calculate the td regression rate
def regression_air_yards(df, td_ratio):
    df['td_reg_rate'] = df['td'] - df['rec_yards']/td_ratio
    touchdowns = df[[
        "full_name", 
        "position",
        "targets",
        "rec_yards",
        "adot",
        "td",
        "tgt_share",
        "ppr",
        "td_reg_rate"
    ]].sort_values('td_reg_rate', ascending=True)
    return touchdowns

test = regression_air_yards(positional(air_yards_18, "WR"),wr_ratio) #input needed values to "positional" and
                                                                     #the needed corresponding postional td_ratio
test.head(10)
# Out:
#          full_name position  targets  rec_yards  adot  td  tgt_share    ppr  \
# 2      Julio Jones       WR      169       1655  14.3   7       0.28  320.7
# 53    Willie Snead       WR       95        649   8.2   1       0.18  134.2
# 37      D.J. Moore       WR       83        788   9.8   2       0.15  163.0
# 16     T.Y. Hilton       WR      118       1248  11.1   5       0.22  228.8
# 67  Danny Amendola       WR       76        565   7.9   1       0.18  119.3
# 15   Brandin Cooks       WR      116       1191  12.7   5       0.22  240.2
# 14    Keenan Allen       WR      137       1188   8.6   5       0.29  252.3
# 42  Taylor Gabriel       WR       91        689  11.5   2       0.18  153.0
# 91     Keelan Cole       WR       67        491   9.9   1       0.15   93.1
# 21   Jarvis Landry       WR      145        958  11.9   4       0.26  211.8
#
#     td_reg_rate
# 2     -3.451206
# 53    -3.098389
# 37    -2.976164
# 16    -2.881031
# 67    -2.567935
# 15    -2.521080
# 14    -2.502135
# 42    -2.350986
# 91    -2.100630
# 21    -2.049701

# %% [markdown]
# Using 2018 as our example, we see that Julio Jones should have scored approx. 3.5 more touchdowns than he did. This statistic can help fantasy owners determine who to trade for or who to trade away. It can help owners decide who to play in any given week and who is underperforming or overperforming in the touchdown column. This statistc, seemingly simple, can be a powerful contributor in determining player acquisition and answering start/sit questions.
#
# Now for aesthetics. Seaborn allows us to visualize columns with color conditional formatting. Using `.diverging_palette` allows us to display positive and negative touchdown candidates with simple visuals. ***This may not appear in github.***

# %%
# We can use conditional formatting and seaborn colormap to better visualize our data
pos_lp = sns.diverging_palette(220,20, as_cmap=True) #220 and 20 relates to colors

(test[(test.td_reg_rate < 0)][["full_name", "td_reg_rate"]] #those underscoring the average
  .head(35)
  .style
  .background_gradient(cmap=pos_lp, subset=["td_reg_rate"])
  .set_caption("Positive Touchdown Regression Candidates")
  .format({"td_reg_rate": "{:.3}"}) #only relay two decimals
)
# Out:
# <style  type="text/css" >
#     #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row0_col1 {
#             background-color:  #3f7f93;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row1_col1 {
#             background-color:  #72a2b1;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row2_col1 {
#             background-color:  #85aebb;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row3_col1 {
#             background-color:  #93b8c3;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row4_col1 {
#             background-color:  #c1d7de;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row5_col1 {
#             background-color:  #c8dce2;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row6_col1 {
#             background-color:  #cbdee4;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row7_col1 {
#             background-color:  #e2eef1;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row8_col1 {
#             background-color:  #f6e6e2;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row9_col1 {
#             background-color:  #f4dfda;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row10_col1 {
#             background-color:  #eed0c8;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row11_col1 {
#             background-color:  #eac2b8;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row12_col1 {
#             background-color:  #e9c1b7;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row13_col1 {
#             background-color:  #e6b8ad;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row14_col1 {
#             background-color:  #e2aea1;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row15_col1 {
#             background-color:  #e2ad9f;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row16_col1 {
#             background-color:  #e0a798;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row17_col1 {
#             background-color:  #dda091;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row18_col1 {
#             background-color:  #dd9f8f;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row19_col1 {
#             background-color:  #dc9d8d;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row20_col1 {
#             background-color:  #da9786;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row21_col1 {
#             background-color:  #d78f7d;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row22_col1 {
#             background-color:  #d2806b;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row23_col1 {
#             background-color:  #ce755e;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row24_col1 {
#             background-color:  #cd735c;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row25_col1 {
#             background-color:  #cc7058;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row26_col1 {
#             background-color:  #c9684f;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row27_col1 {
#             background-color:  #c8644b;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row28_col1 {
#             background-color:  #c8634a;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row29_col1 {
#             background-color:  #c76148;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row30_col1 {
#             background-color:  #c76148;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row31_col1 {
#             background-color:  #c76046;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row32_col1 {
#             background-color:  #c65f45;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row33_col1 {
#             background-color:  #c3573b;
#             color:  #000000;
#         }    #T_de468cb4_78ff_11ea_9d96_c49ded01ef66row34_col1 {
#             background-color:  #c3553a;
#             color:  #000000;
#         }</style><table id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66" ><caption>Positive Touchdown Regression Candidates</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >full_name</th>        <th class="col_heading level0 col1" >td_reg_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row0_col0" class="data row0 col0" >Julio Jones</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row0_col1" class="data row0 col1" >-3.45</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row1" class="row_heading level0 row1" >53</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row1_col0" class="data row1 col0" >Willie Snead</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row1_col1" class="data row1 col1" >-3.1</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row2" class="row_heading level0 row2" >37</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row2_col0" class="data row2 col0" >D.J. Moore</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row2_col1" class="data row2 col1" >-2.98</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row3" class="row_heading level0 row3" >16</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row3_col0" class="data row3 col0" >T.Y. Hilton</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row3_col1" class="data row3 col1" >-2.88</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row4" class="row_heading level0 row4" >67</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row4_col0" class="data row4 col0" >Danny Amendola</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row4_col1" class="data row4 col1" >-2.57</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row5" class="row_heading level0 row5" >15</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row5_col0" class="data row5 col0" >Brandin Cooks</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row5_col1" class="data row5 col1" >-2.52</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row6" class="row_heading level0 row6" >14</th>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row6_col0" class="data row6 col0" >Keenan Allen</td>
#                         <td id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66row6_col1" class="data row6 col1" >-2.5</td>
#             </tr>
#             <tr>
#                         <th id="T_de468cb4_78ff_11ea_9d96_c49ded01ef66level0_row7" class="row_heading level0 row7" >42</th>
#                         <td id="T_de468cb4_78ff_1

# %%
neg_lp = sns.diverging_palette(100, 40, as_cmap=True) #100 and 40 relates to color

(test[(test.td_reg_rate > 0)][["full_name", "td_reg_rate"]] #those outscoring the average
  .sort_values("td_reg_rate", ascending=False) #Must sort by descending to flip the column
  .head(35)
  .style
  .background_gradient(cmap=neg_lp, subset=["td_reg_rate"])
  .set_caption("Negative Touchdown Regression Candidates")
  .format({"td_reg_rate": "{:.3}"}) #only relay two decimals
)
# Out:
# <style  type="text/css" >
#     #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row0_col1 {
#             background-color:  #a26b39;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row1_col1 {
#             background-color:  #c5a181;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row2_col1 {
#             background-color:  #c9a88a;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row3_col1 {
#             background-color:  #e2cfbf;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row4_col1 {
#             background-color:  #efe4d9;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row5_col1 {
#             background-color:  #f2e7de;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row6_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row7_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row8_col1 {
#             background-color:  #cad1b4;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row9_col1 {
#             background-color:  #bbc3a0;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row10_col1 {
#             background-color:  #b6bf9a;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row11_col1 {
#             background-color:  #b4be98;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row12_col1 {
#             background-color:  #b2bc95;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row13_col1 {
#             background-color:  #a6b184;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row14_col1 {
#             background-color:  #9fab7b;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row15_col1 {
#             background-color:  #9eaa7a;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row16_col1 {
#             background-color:  #9ba776;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row17_col1 {
#             background-color:  #929f6a;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row18_col1 {
#             background-color:  #909d67;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row19_col1 {
#             background-color:  #8e9b65;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row20_col1 {
#             background-color:  #8d9a63;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row21_col1 {
#             background-color:  #8c9962;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row22_col1 {
#             background-color:  #8c9962;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row23_col1 {
#             background-color:  #8b9860;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row24_col1 {
#             background-color:  #89975d;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row25_col1 {
#             background-color:  #86955b;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row26_col1 {
#             background-color:  #849358;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row27_col1 {
#             background-color:  #829054;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row28_col1 {
#             background-color:  #7e8e50;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row29_col1 {
#             background-color:  #7c8c4d;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row30_col1 {
#             background-color:  #7b8b4c;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row31_col1 {
#             background-color:  #738441;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row32_col1 {
#             background-color:  #738441;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row33_col1 {
#             background-color:  #738441;
#             color:  #000000;
#         }    #T_de566c1a_78ff_11ea_8c27_c49ded01ef66row34_col1 {
#             background-color:  #6d7e39;
#             color:  #000000;
#         }</style><table id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66" ><caption>Negative Touchdown Regression Candidates</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >full_name</th>        <th class="col_heading level0 col1" >td_reg_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row0_col0" class="data row0 col0" >Antonio Brown</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row0_col1" class="data row0 col1" >6.96</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row1" class="row_heading level0 row1" >32</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row1_col0" class="data row1 col0" >Mike Williams</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row1_col1" class="data row1 col1" >5.81</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row2" class="row_heading level0 row2" >100</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row2_col0" class="data row2 col0" >John Ross</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row2_col1" class="data row2 col1" >5.67</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row3" class="row_heading level0 row3" >23</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row3_col0" class="data row3 col0" >Calvin Ridley</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row3_col1" class="data row3 col1" >4.85</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row4" class="row_heading level0 row4" >70</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row4_col0" class="data row4 col0" >Anthony Miller</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row4_col1" class="data row4 col1" >4.42</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row5" class="row_heading level0 row5" >1</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row5_col0" class="data row5 col0" >Davante Adams</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row5_col1" class="data row5 col1" >4.35</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row6" class="row_heading level0 row6" >133</th>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row6_col0" class="data row6 col0" >Jaron Brown</td>
#                         <td id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66row6_col1" class="data row6 col1" >3.95</td>
#             </tr>
#             <tr>
#                         <th id="T_de566c1a_78ff_11ea_8c27_c49ded01ef66level0_row7" class="row_heading level0 row7" >19</th>
#                         <td id="T_de566c1a_78ff_11

# %% [markdown]
# The function ***regression_air_yards*** takes the conclusive dataset from function ***positional***  and the previous calculated corresponding positional touchdown ratio and determines how many more touchdowns a wide receiver/tight end should have based off the averages of 8 years worth of receiving data. We can determine positive and negative regression candidates through this calculation. Having found a strong correlation between receiving yards and receiving touchdowns, we know that, on average, a receiver scores one touchdown on every 159 receiving yards and a tight end scores one touchdown on every 129 receiving yards. If a receiver is likely to get a similar amount of usage/work, it is fair to think that the positive touchdown candidates should, at some point, score touchdowns, which aids in fantasy point accumulation. An important thing to keep in mind - a touchdown regression rate is NOT an overcorrection.
#
# An example for future use: let us say that after week 4 of the 2020 season, JuJu Smith-Schuster has a ***td_reg_rate*** of approx. -3. This value tells us that, based off his receiving yards, he is underperforming (as it relates to an average wide receiver) by 3 touchdowns. If he continues to get similar work and produces similar yardage, he should begin to score touchdowns. It does not mean we should expect a 3 touchdown game in week 5 from JuJu. But that he should eventually regress to the mean and begin to start scoring touchdowns more to the average of 159 receiving yards per one touchdown.
#
# Of course there are many factors that can drive touchdown success rate but, knowing the correlation of receiving yards to receiving touchdowns and knowing that touchdowns regress aids fantasy football owners in making executive decisions about their lineup.
